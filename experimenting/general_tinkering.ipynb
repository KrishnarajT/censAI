# %%
import pandas as pd
import numpy as np

# load data from P:\programs\DSML\censAI\shows\Game of Thrones\temp\1
root_folder = r'P:\programs\DSML\censAI\shows\Game of Thrones\temp\1'

# load dfs from pickle files
all_scenes_df = pd.read_pickle(f'{root_folder}/all_scenes_df.pkl')
scene_images_db = pd.read_pickle(f'{root_folder}/scene_images_db.pkl')
current_scenes_df = pd.read_pickle(f'{root_folder}/current_scenes_df.pkl')

# %%
all_scenes_df
# Out:
#        timestamp  video_id scene_number scene_snapshot_number  \
# 0             41       NaN          001                   NaN
# 1             41       NaN          001                   NaN
# 2            800       5.0         None                   NaN
# 3           5463       NaN          001                   NaN
# 4           5463       NaN          001                   NaN
# ...          ...       ...          ...                   ...
# 13113    3690019       NaN          948                   NaN
# 13114    3690144       NaN          949                   NaN
# 13115    3690144       NaN          949                   NaN
# 13116    3693648       NaN          949                   NaN
# 13117    3693648       NaN          949                   NaN
#
#       scene_snapshot_path                                 subtitle  \
# 0                     NaN                                      NaN
# 1                     NaN                                      NaN
# ...
